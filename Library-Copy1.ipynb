# %% [markdown]
# ## Current Working Functions of `week_to_week.py`

# %%
import week_to_week as ps
import nfl_data_py as nfl
import tables as tb

# %%
te = ps.tight_end([1], 'points')
wr = ps.wide_receiver([1], 'points')
rb = ps.rb_usage([1])

# %%
#(Data, cart type(str), number of players)
#Tight end data is interchangable here
ps.wr_plots(wr, 'wopr', 30)
# Out:
# WOPR=1.5 * Target Market Share + 0.7 * Air Yards Market Share
# Measures volume, want lots of targets and high air yards. Ideally 70 or higher

# %%
ps.wr_plots(te, 'racr', 30)
# Out:
# RACR = Recieving Yards / Air Yards
# Efficient player's ratio is generally 1 or higher

# %%
#Target Share
ps.wr_plots(wr, 'tgt', 30)

# %%
#Rb usage - Who's getting the touches
# (rb data, chart type(bar, scatter, or both), amount of players)
ps.plot_rb_usage(rb, 'bar', 25)

# %%
#Scatter plot, rb usage rank & fantasy points rank
# Being on the lower end of the y axis is good (high points)
ps.plot_rb_usage(rb, 'scatter', 40)

# %%
#plot yards per carry(week, amount of players)
ps.plot_ypc([1], 30)

# %%
ps.receiver_rating([1], 30)

# %%
tb.wr_usage(1)
# Out:
# Differences vs. 2023 Season Average. Week 1 Data.
# <style type="text/css">
# #T_c36eb thead th {
#   background-color: grey;
#   color: black;
#   font-weight: bold;
#   text-align: center;
# }
# #T_c36eb td {
#   padding: 5px;
# }
# ...

# %%
tb.wr_performance(1)
# Out:
# Differences vs. 2023 Season Average. Week 1 Data.
# <style type="text/css">
# #T_ce855 thead th {
#   background-color: grey;
#   color: black;
#   font-weight: bold;
#   text-align: center;
# }
# #T_ce855 td {
#   padding: 5px;
# }
# ...

# %%
tb.rb_usage(1)
# Out:
# Differences vs. 2023 Season Average, Week 1 Data.
# <style type="text/css">
# #T_1cef8 thead th {
#   background-color: grey;
#   color: black;
#   font-weight: bold;
#   text-align: center;
# }
# #T_1cef8 td {
#   padding: 5px;
# }
# ...

# %%
tb.rb_performance(1)
# Out:
# <style type="text/css">
# #T_1d8e0 thead th {
#   background-color: grey;
#   color: black;
#   font-weight: bold;
#   text-align: center;
# }
# #T_1d8e0 td {
#   padding: 5px;
# }
# ...

# %%
tb.te_usage(1)
# Out:
# <style type="text/css">
# #T_7e615 thead th {
#   background-color: grey;
#   color: black;
#   font-weight: bold;
#   text-align: center;
# }
# #T_7e615 td {
#   padding: 5px;
# }
# ...

# %%
tb.te_performance(1)
# Out:
# Differences vs. 2023 Season Average, Week 1 Data.
# <style type="text/css">
# #T_0d164 thead th {
#   background-color: grey;
#   color: black;
#   font-weight: bold;
#   text-align: center;
# }
# #T_0d164 td {
#   padding: 5px;
# }
# ...

# %%
tb.qb_usage(1)
# Out:
# Differences vs. 2023 Season Average, Week 1 Data.
# <style type="text/css">
# #T_01afe thead th {
#   background-color: grey;
#   color: black;
#   font-weight: bold;
#   text-align: center;
# }
# #T_01afe td {
#   padding: 5px;
# }
# ...

# %%
tb.qb_performance(1)
# Out:
# <style type="text/css">
# #T_e1dc7 thead th {
#   background-color: grey;
#   color: black;
#   font-weight: bold;
#   text-align: center;
# }
# #T_e1dc7 td {
#   padding: 5px;
# }
# ...
